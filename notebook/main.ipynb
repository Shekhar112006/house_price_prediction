# %%
import sys
import os

# this must show .../house-price-prediction-ml/notebook
print("Current working directory:", os.getcwd())

# this must list your .py files
print("SRC folder contents:", os.listdir("../src"))

# add src to python path
sys.path.append(os.path.abspath("../src"))
# Out:
# Current working directory: c:\Users\ak\OneDrive\Desktop\house+price_prediction\notebook
# SRC folder contents: ['data_preprocessing.py', 'model_training.py', 'predict.py', '__pycache__']

# %%
from data_preprocessing import load_and_split_data
from model_training import train_model, evaluate_model
from predict import predict_price

print("Imports successful ✅")
# Out:
# Imports successful ✅

# %%
# 1️⃣ Load & split the dataset
X_train, X_test, y_train, y_test = load_and_split_data("C:/Users/ak/OneDrive/Desktop/house+price_prediction/dataset/dataset.csv")
print("✅ Data loaded and split successfully")

# 2️⃣ Train the model
model = train_model(X_train, y_train)
print("✅ Model trained successfully")

# 3️⃣ Evaluate the model
evaluate_model(model, X_test, y_test)

# 4️⃣ Make a prediction
predicted_price = predict_price(model, area=2000, bedrooms=3, bathrooms=2)
print(f"✅ Predicted House Price: {predicted_price}")
# Out:
# ✅ Data loaded and split successfully
# ✅ Model trained successfully
# ✅ Predicted House Price: 5999999.999999996
# c:\Users\ak\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
